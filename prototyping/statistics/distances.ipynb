D_p1_frame600 = np.array([104.94812118402926,123.78014739617845,71.09779477752843, 47.26387105959464,
    23.525758125911974, 81.27149442214899, 57.77046881481278, 42.87739988776435, 71.39025954173347,
    42.206194395571174, 57.946931378953174, 87.87866752332397, 66.36316400981079, 73.25036937190796])
D_p2_frame600 = np.array([76.14884110116466,452.34352892585315, 47.83861864997495, 43.872403529177646,
    60.861874629120884,  90.08001725919385,  27.548965689436326, 45.78880451290202, 55.79612875220025,
    47.154601354320555,  49.64680371016124, 69.79691436123923, 13.50052914275833,  22.354188902847163])

# --- Frame 700 ---
D_p1_frame700 = np.array([96.0574440305863, 417.4124417908733, 80.21544242412426, 40.459235190499065,
    57.76623620278413, 59.098900367503866, 37.867321704391955, 86.261869008156, 41.26424375790778,
    43.90384645125398, 27.127348678292048, 55.96812456511296,  41.63037758356934,  21.43234481667986])
D_p2_frame700 = np.array([62.23567748243466, 75.19088069856257,  102.19468421416515,  20.2097877490488,
    29.35577164088552, 123.9866874474679, 74.44947729935947, 52.8747345747639,  65.88825045468381,
    32.09388145696361,  57.66609801405169,94.48056622254161,23.092730765656572, 47.55556501242564])

P1 = np.array([
    D_p1_frame0, D_p1_frame100, D_p1_frame200, D_p1_frame300, D_p1_frame400, D_p1_frame500, 
    D_p1_frame600, D_p1_frame700
])

P2 = np.array([
    D_p2_frame0, D_p2_frame100, D_p2_frame200, D_p2_frame300, D_p2_frame400, D_p2_frame500, 
    D_p2_frame600, D_p2_frame700
])

# * head (0)
# * neck (1)
# * left-shoulder (2)
# * left-elbow (3)
# * left-hand (4)
# * right-shoulder (5)
# * right-elbow (6)
# * right-hand (7)
# * left-hip (8)
# * left-knee (9)
# * left-foot (10)
# * right-hip (11)
# * right-knee (12)
# * right-foot (13)

HEAD = np.concatenate([P1[:,0], P2[:,0]])
NECK = np.concatenate([P1[:,1], P2[:,1]])
LSHOU = np.concatenate([P1[:,2], P2[:,2]])
LELBW = np.concatenate([P1[:,3], P2[:,3]])
LHAND = np.concatenate([P1[:,4], P2[:,4]])
RSHOU = np.concatenate([P1[:,5], P2[:,5]])
RELBW = np.concatenate([P1[:,6], P2[:,6]])
RHAND = np.concatenate([P1[:,7], P2[:,7]])
LHIP = np.concatenate([P1[:,8], P2[:,8]])
LKNEE = np.concatenate([P1[:,9], P2[:,9]])
LFOOT = np.concatenate([P1[:,10], P2[:,10]])
RHIP = np.concatenate([P1[:,11], P2[:,11]])
RKNEE = np.concatenate([P1[:,12], P2[:,12]])
RFOOT = np.concatenate([P1[:,13], P2[:,13]])

L = [
    HEAD,NECK,LSHOU,LELBW,LHAND,RSHOU,RELBW,RHAND,LHIP,LKNEE,LFOOT,
    RHIP,RKNEE,RFOOT
]

# %%
#RHAND[(RHAND > 0).nonzero()]

#np.mean(RHAND[(RHAND > 0).nonzero()])

Total = np.concatenate([P1, P2], axis=0)

Total.shape
# Out:
# (16, 14)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# * head (1)
# * neck (2)
# * left-shoulder (3)
# * left-elbow (4)
# * left-hand (5)
# * right-shoulder (6)
# * right-elbow (7)
# * right-hand (8)
# * left-hip (9)
# * left-knee (10)
# * left-foot (11)
# * right-hip (12)
# * right-knee (13)
# * right-foot (14)

Names = [
    'head', 'neck', 
    'lshoulder', 'lelbow', 'lhand',
    'rshoulder', 'relbow', 'rhand',
    'lhip', 'lknee', 'lfoot',
    'rhip', 'rknee', 'rfoot'
]

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

ax.boxplot(Total, vert=False, patch_artist=True, notch=True)
ax.set_xlabel('mm', fontsize=14)

ax.set_yticklabels(Names, fontsize=14)

#plt.show()
#plt.savefig('umpm.eps', dpi=None, format='eps')
#plt.savefig('umpm.png', dpi=None, format='png')

plt.savefig('umpm.svg', dpi=None, format='svg')
