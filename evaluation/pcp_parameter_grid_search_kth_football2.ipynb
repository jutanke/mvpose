# %%
# %matplotlib inline

import json
Settings = json.load(open('../settings.txt'))
import matplotlib.pyplot as plt
import numpy as np
from os.path import join
from cselect import color as cs
import sys
sys.path.insert(0,'../')
sys.path.insert(0,'../samples')
from mvpose.data import epfl_campus
from time import time

root = Settings['data_root']
root = join(root, 'pak')
tmp = Settings['tmp']
data_root = Settings['data_root']

import mvpose.data.kth_football2 as kth
from mvpose import pose
from mvpose.settings import get_settings
from paf_loader import Loader
from mvpose.evaluation import pcp

import mvpose.data.skeleton_augmentation as ska
model_path = '../data/model_poseprediction.h5'
gen = ska.LimbGenerator(model_path, 1000)

# ----------------------------------
seq1_zipname = 'player2sequence1.zip'
seq1_dir = 'Sequence 1'
# ----------------------------------
# Out:
# /home/tanke/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# ====================================================
# Extractor Functions
# ====================================================
def extract_best(pos3d, Humans, alpha):
    """
        Extracts the best fitting human for the calculation
    """
    larms = 0
    uarms = 0
    ulegs = 0
    llegs = 0
    all_parts = 0
    
    for h in Humans:
        r = pcp.evaluate(pos3d, Humans[0], alpha)
        if all_parts < r.all_parts:
            larms = r.lower_arms
            uarms = r.upper_arms
            ulegs = r.upper_legs
            llegs = r.lower_legs
    
    return {
        "larms": larms,
        "uarms": uarms,
        "ulegs": ulegs,
        "llegs": llegs
    }

loader = Loader()

def apply(frame, alpha, loader):
    """
    """
    global seq1_zipname, seq1_zip
    Im, Calib, pos2d, pos3d = kth.get(
        data_root, seq1_zipname, seq1_dir, frame, player=2)
    heatmaps, pafs = loader.load_confidence_map_and_paf(
        'kth' + seq1_zipname[0:-4], Im, frame, dir=Settings['tmp'])
    
    detections = pose.estimate(Calib, heatmaps, pafs, 
                           settings=params)

    #detections = gen.apply(detections)
    
    if len(detections) == 0:
        return {
            "larms": 0,
            "uarms": 0,
            "ulegs": 0,
            "llegs": 0
        }
        
    
    Humans = kth.transform3d_from_mscoco(detections)
    result = extract_best(pos3d, Humans, alpha)
    return result

# ======================================
# RUN
# ======================================

# MEAN SHIFT

ms_radius = [20, 30, 40, 50, 60, 70, 90, 110, 120, 130, 140]
ms_between_distances = [30, 50, 60, 70, 90, 110, 120, 130, 150]

TESTS = []
for radius in ms_radius:
    for between_distance in ms_between_distances:
        
        _START = time()
        print('\n--- next step ---')
        print('radius:', radius)
        print('between_distance:', between_distance)
        
        valid_frames = range(0, 214, 5)
        
        params = get_settings(scale_to_mm=1000,
                          gp_max_radius=150,
                          min_nbr_joints=5,
                          max_epi_distance=25,
                          hm_detection_threshold=0.05,
                          pp_conflict_overlap=0.4,
                          ms_radius=radius,
                          ms_between_distance=between_distance)
        
        CURRENT = []
        for frame in valid_frames:
            if frame % 5 == 0:
                print('\tstep:', frame)
            result = apply(frame, 0.5, loader)
            CURRENT.append(result)
         
        avg = {
            "larms": 0,
            "uarms": 0,
            "ulegs": 0,
            "llegs": 0
        }
        for cur in CURRENT:
            avg['larms'] += cur['larms']
            avg['uarms'] += cur['uarms']
            avg['ulegs'] += cur['ulegs']
            avg['llegs'] += cur['llegs']
        avg['larms'] = avg['larms']/len(CURRENT)
        avg['uarms'] = avg['uarms']/len(CURRENT)
        avg['ulegs'] = avg['ulegs']/len(CURRENT)
        avg['llegs'] = avg['llegs']/len(CURRENT)
        TESTS.append(avg)
        
        _END = time()
        print('total step ELAPSED:', _END - _START)

i = 0

IMG = np.zeros((len(ms_radius), len(ms_between_distances)), 'float32')

for a, radius in enumerate(ms_radius):
    for b, between_distance in enumerate(ms_between_distances):
        print('radius:', radius)
        print('between-distance:', between_distance)
        total_avg = []
        
        CUR = TESTS[i]
        i += 1
        
        avg = np.mean([
            CUR['larms'], CUR['uarms'], CUR['ulegs'], CUR['llegs']
        ])
        
        print('\navg*:  ', avg)
        IMG[a,b] = avg
        print('')

fig = plt.figure(figsize=(10, 12))
ax = fig.add_subplot(111)

heatmap = ax.pcolor(IMG)
cbar = plt.colorbar(heatmap)

plt.show()
# Out:
# --- next step ---
# radius: 20
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 289.49860858917236
#
# --- next step ---
# radius: 20
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 49.18120217323303
#
# --- next step ---
# radius: 20
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 47.0269718170166
#
# --- next step ---
# radius: 20
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.64541530609131
#
# --- next step ---
# radius: 20
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.57178831100464
#
# --- next step ---
# radius: 20
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.12440848350525
#
# --- next step ---
# radius: 20
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 34.87301540374756
#
# --- next step ---
# radius: 20
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.04524230957031
#
# --- next step ---
# radius: 20
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.267799377441406
#
# --- next step ---
# radius: 30
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 157.75838112831116
#
# --- next step ---
# radius: 30
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 55.19500803947449
#
# --- next step ---
# radius: 30
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 45.10603332519531
#
# --- next step ---
# radius: 30
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.828033685684204
#
# --- next step ---
# radius: 30
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.934789419174194
#
# --- next step ---
# radius: 30
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.1189866065979
#
# --- next step ---
# radius: 30
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.017226219177246
#
# --- next step ---
# radius: 30
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 34.96461772918701
#
# --- next step ---
# radius: 30
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 34.95635223388672
#
# --- next step ---
# radius: 40
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 85.08754777908325
#
# --- next step ---
# radius: 40
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 62.60788059234619
#
# --- next step ---
# radius: 40
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 50.94353914260864
#
# --- next step ---
# radius: 40
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 41.828776836395264
#
# --- next step ---
# radius: 40
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.26173639297485
#
# --- next step ---
# radius: 40
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.606061935424805
#
# --- next step ---
# radius: 40
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.428558349609375
#
# --- next step ---
# radius: 40
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.3255033493042
#
# --- next step ---
# radius: 40
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.1414098739624
#
# --- next step ---
# radius: 50
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 53.20612621307373
#
# --- next step ---
# radius: 50
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 52.83191251754761
#
# --- next step ---
# radius: 50
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 53.80648636817932
#
# --- next step ---
# radius: 50
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 43.93134832382202
#
# --- next step ---
# radius: 50
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.45690059661865
#
# --- next step ---
# radius: 50
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.40360140800476
#
# --- next step ---
# radius: 50
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.61120533943176
#
# --- next step ---
# radius: 50
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.18528962135315
#
# --- next step ---
# radius: 50
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.196855545043945
#
# --- next step ---
# radius: 60
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 49.627657413482666
#
# --- next step ---
# radius: 60
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 47.839598178863525
#
# --- next step ---
# radius: 60
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 47.263198375701904
#
# --- next step ---
# radius: 60
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 44.04737734794617
#
# --- next step ---
# radius: 60
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.848387718200684
#
# --- next step ---
# radius: 60
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.45233345031738
#
# --- next step ---
# radius: 60
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.904890060424805
#
# --- next step ---
# radius: 60
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.60026144981384
#
# --- next step ---
# radius: 60
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 35.67978596687317
#
# --- next step ---
# radius: 70
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 40.18317794799805
#
# --- next step ---
# radius: 70
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 40.317628145217896
#
# --- next step ---
# radius: 70
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 40.34239959716797
#
# --- next step ---
# radius: 70
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 41.170615673065186
#
# --- next step ---
# radius: 70
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.81967806816101
#
# --- next step ---
# radius: 70
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.16686177253723
#
# --- next step ---
# radius: 70
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.157734870910645
#
# --- next step ---
# radius: 70
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.80649471282959
#
# --- next step ---
# radius: 70
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.701568365097046
#
# --- next step ---
# radius: 90
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 39.012892723083496
#
# --- next step ---
# radius: 90
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 38.19629240036011
#
# --- next step ---
# radius: 90
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.42271709442139
#
# --- next step ---
# radius: 90
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.87657284736633
#
# --- next step ---
# radius: 90
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.961588621139526
#
# --- next step ---
# radius: 90
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.49367094039917
#
# --- next step ---
# radius: 90
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.92527770996094
#
# --- next step ---
# radius: 90
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.15633726119995
#
# --- next step ---
# radius: 90
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.37242937088013
#
# --- next step ---
# radius: 110
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.82243609428406
#
# --- next step ---
# radius: 110
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.47287321090698
#
# --- next step ---
# radius: 110
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.53584694862366
#
# --- next step ---
# radius: 110
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.45457458496094
#
# --- next step ---
# radius: 110
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.90140700340271
#
# --- next step ---
# radius: 110
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.773818016052246
#
# --- next step ---
# radius: 110
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.74308943748474
#
# --- next step ---
# radius: 110
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.390732765197754
#
# --- next step ---
# radius: 110
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.33765244483948
#
# --- next step ---
# radius: 120
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.66862201690674
#
# --- next step ---
# radius: 120
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.542659759521484
#
# --- next step ---
# radius: 120
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.48978114128113
#
# --- next step ---
# radius: 120
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.45726180076599
#
# --- next step ---
# radius: 120
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.60879921913147
#
# --- next step ---
# radius: 120
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.39791488647461
#
# --- next step ---
# radius: 120
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.33157396316528
#
# --- next step ---
# radius: 120
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.39688205718994
#
# --- next step ---
# radius: 120
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.501728534698486
#
# --- next step ---
# radius: 130
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 38.541746616363525
#
# --- next step ---
# radius: 130
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.208659172058105
#
# --- next step ---
# radius: 130
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.89317750930786
#
# --- next step ---
# radius: 130
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.1911826133728
#
# --- next step ---
# radius: 130
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.65289759635925
#
# --- next step ---
# radius: 130
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.45772051811218
#
# --- next step ---
# radius: 130
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.65704917907715
#
# --- next step ---
# radius: 130
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 37.030253648757935
#
# --- next step ---
# radius: 130
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.69506359100342
#
# --- next step ---
# radius: 140
# between_distance: 30
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.97627258300781
#
# --- next step ---
# radius: 140
# between_distance: 50
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.17357110977173
#
# --- next step ---
# radius: 140
# between_distance: 60
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.16266369819641
#
# --- next step ---
# radius: 140
# between_distance: 70
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.13131332397461
#
# --- next step ---
# radius: 140
# between_distance: 90
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.229347467422485
#
# --- next step ---
# radius: 140
# between_distance: 110
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.744032859802246
#
# --- next step ---
# radius: 140
# between_distance: 120
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.745450496673584
#
# --- next step ---
# radius: 140
# between_distance: 130
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.63710808753967
#
# --- next step ---
# radius: 140
# between_distance: 150
# 	step: 0
# 	step: 5
# 	step: 10
# 	step: 15
# 	step: 20
# 	step: 25
# 	step: 30
# 	step: 35
# 	step: 40
# 	step: 45
# 	step: 50
# 	step: 55
# 	step: 60
# 	step: 65
# 	step: 70
# 	step: 75
# 	step: 80
# 	step: 85
# 	step: 90
# 	step: 95
# 	step: 100
# 	step: 105
# 	step: 110
# 	step: 115
# 	step: 120
# 	step: 125
# 	step: 130
# 	step: 135
# 	step: 140
# 	step: 145
# 	step: 150
# 	step: 155
# 	step: 160
# 	step: 165
# 	step: 170
# 	step: 175
# 	step: 180
# 	step: 185
# 	step: 190
# 	step: 195
# 	step: 200
# 	step: 205
# 	step: 210
# total step ELAPSED: 36.578043699264526
# radius: 20
# between-distance: 30
#
# avg*:   0.9098837209302325
#
# radius: 20
# between-distance: 50
#
# avg*:   0.9098837209302325
#
# radius: 20
# between-distance: 60
#
# avg*:   0.8953488372093023
#
# radius: 20
# between-distance: 70
#
# avg*:   0.8895348837209301
#
# radius: 20
# between-distance: 90
#
# avg*:   0.9040697674418604
#
# radius: 20
# between-distance: 110
#
# avg*:   0.9011627906976744
#
# radius: 20
# between-distance: 120
#
# avg*:   0.8924418604651163
#
# radius: 20
# between-distance: 130
#
# avg*:   0.9011627906976744
#
# radius: 20
# between-distance: 150
#
# avg*:   0.8924418604651162
#
# radius: 30
# between-distance: 30
#
# avg*:   0.9098837209302325
#
# radius: 30
# between-distance: 50
#
# avg*:   0.9040697674418604
#
# radius: 30
# between-distance: 60
#
# avg*:   0.8953488372093023
#
# radius: 30
# between-distance: 70
#
# avg*:   0.8924418604651162
#
# radius: 30
# between-distance: 90
#
# avg*:   0.9069767441860465
#
# radius: 30
# between-distance: 110
#
# avg*:   0.9040697674418604
#
# radius: 30
# between-distance: 120
#
# avg*:   0.9011627906976744
#
# radius: 30
# between-distance: 130
#
# avg*:   0.9069767441860465
#
# radius: 30
# between-distance: 150
#
# avg*:   0.8924418604651162
#
# radius: 40
# between-distance: 30
#
# avg*:   0.9098837209302325
#
# radius: 40
# between-distance: 50
#
# avg*:   0.9127906976744186
#
# radius: 40
# between-distance: 60
#
# avg*:   0.9098837209302325
#
# radius: 40
# between-distance: 70
#
# avg*:   0.8982558139534883
#
# radius: 40
# between-distance: 90
#
# avg*:   0.9011627906976744
#
# radius: 40
# between-distance: 110
#
# avg*:   0.9011627906976744
#
# radius: 40
# between-distance: 120
#
# avg*:   0.9011627906976745
#
# radius: 40
# between-distance: 130
#
# avg*:   0.9127906976744186
#
# radius: 40
# between-distance: 150
#
# avg*:   0.8895348837209303
#
# radius: 50
# between-distance: 30
#
# avg*:   0.9040697674418604
#
# radius: 50
# between-distance: 50
#
# avg*:   0.9040697674418604
#
# radius: 50
# between-distance: 60
#
# avg*:   0.9069767441860465
#
# radius: 50
# between-distance: 70
#
# avg*:   0.8953488372093023
#
# radius: 50
# between-distance: 90
#
# avg*:   0.8982558139534883
#
# radius: 50
# between-distance: 110
#
# avg*:   0.9069767441860465
#
# radius: 50
# between-distance: 120
#
# avg*:   0.9098837209302325
#
# radius: 50
# between-distance: 130
#
# avg*:   0.9215116279069767
#
# radius: 50
# between-distance: 150
#
# avg*:   0.8953488372093023
#
# radius: 60
# between-distance: 30
#
# avg*:   0.9069767441860465
#
# radius: 60
# between-distance: 50
#
# avg*:   0.8953488372093023
#
# radius: 60
# between-distance: 60
#
# avg*:   0.8953488372093023
#
# radius: 60
# between-distance: 70
#
# avg*:   0.8895348837209301
#
# radius: 60
# between-distance: 90
#
# avg*:   0.9040697674418604
#
# radius: 60
# between-distance: 110
#
# avg*:   0.9011627906976744
#
# radius: 60
# between-distance: 120
#
# avg*:   0.9040697674418604
#
# radius: 60
# between-distance: 130
#
# avg*:   0.9156976744186046
#
# radius: 60
# between-distance: 150
#
# avg*:   0.8924418604651162
#
# radius: 70
# between-distance: 30
#
# avg*:   0.8924418604651162
#
# radius: 70
# between-distance: 50
#
# avg*:   0.8924418604651162
#
# radius: 70
# between-distance: 60
#
# avg*:   0.8924418604651162
#
# radius: 70
# between-distance: 70
#
# avg*:   0.8924418604651162
#
# radius: 70
# between-distance: 90
#
# avg*:   0.9040697674418604
#
# radius: 70
# between-distance: 110
#
# avg*:   0.9011627906976744
#
# radius: 70
# between-distance: 120
#
# avg*:   0.9011627906976744
#
# radius: 70
# between-distance: 130
#
# avg*:   0.9186046511627907
#
# radius: 70
# between-distance: 150
#
# avg*:   0.8953488372093023
#
# radius: 90
# between-distance: 30
#
# avg*:   0.9040697674418604
#
# radius: 90
# between-distance: 50
#
# avg*:   0.9040697674418604
#
# radius: 90
# between-distance: 60
#
# avg*:   0.9011627906976744
#
# radius: 90
# between-distance: 70
#
# avg*:   0.9040697674418604
#
# radius: 90
# between-distance: 90
#
# avg*:   0.9011627906976744
#
# radius: 90
# between-distance: 110
#
# avg*:   0.9098837209302325
#
# radius: 90
# between-distance: 120
#
# avg*:   0.9244186046511628
#
# radius: 90
# between-distance: 130
#
# avg*:   0.9156976744186046
#
# radius: 90
# between-distance: 150
#
# avg*:   0.8924418604651162
#
# radius: 110
# between-distance: 30
#
# avg*:   0.9127906976744186
#
# radius: 110
# between-distance: 50
#
# avg*:   0.9127906976744186
#
# radius: 110
# between-distance: 60
#
# avg*:   0.9127906976744186
#
# radius: 110
# between-distance: 70
#
# avg*:   0.9098837209302325
#
# radius: 110
# between-distance: 90
#
# avg*:   0.9098837209302325
#
# radius: 110
# between-distance: 110
#
# avg*:   0.9098837209302325
#
# radius: 110
# between-distance: 120
#
# avg*:   0.9186046511627907
#
# radius: 110
# between-distance: 130
#
# avg*:   0.9127906976744186
#
# radius: 110
# between-distance: 150
#
# avg*:   0.8982558139534883
#
# radius: 120
# between-distance: 30
#
# avg*:   0.9098837209302325
#
# radius: 120
# between-distance: 50
#
# avg*:   0.9098837209302325
#
# radius: 120
# between-distance: 60
#
# avg*:   0.9098837209302325
#
# radius: 120
# between-distance: 70
#
# avg*:   0.9069767441860465
#
# radius: 120
# between-distance: 90
#
# avg*:   0.9040697674418604
#
# radius: 120
# between-distance: 110
#
# avg*:   0.9040697674418604
#
# radius: 120
# between-distance: 120
#
# avg*:   0.9040697674418604
#
# radius: 120
# between-distance: 130
#
# avg*:   0.8982558139534883
#
# radius: 120
# between-distance: 150
#
# avg*:   0.8895348837209301
#
# radius: 130
# between-distance: 30
#
# avg*:   0.9011627906976744
#
# radius: 130
# between-distance: 50
#
# avg*:   0.9011627906976744
#
# radius: 130
# between-distance: 60
#
# avg*:   0.9011627906976744
#
# radius: 130
# between-distance: 70
#
# avg*:   0.8982558139534883
#
# radius: 130
# between-distance: 90
#
# avg*:   0.8982558139534883
#
# radius: 130
# between-distance: 110
#
# avg*:   0.8982558139534883
#
# radius: 130
# between-distance: 120
#
# avg*:   0.8953488372093024
#
# radius: 130
# between-distance: 130
#
# avg*:   0.8953488372093024
#
# radius: 130
# between-distance: 150
#
# avg*:   0.8982558139534883
#
# radius: 140
# between-distance: 30
#
# avg*:   0.9069767441860465
#
# radius: 140
# between-distance: 50
#
# avg*:   0.9069767441860465
#
# radius: 140
# between-distance: 60
#
# avg*:   0.9069767441860465
#
# radius: 140
# between-distance: 70
#
# avg*:   0.9040697674418604
#
# radius: 140
# between-distance: 90
#
# avg*:   0.9040697674418604
#
# radius: 140
# between-distance: 110
#
# avg*:   0.9040697674418604
#
# radius: 140
# between-distance: 120
#
# avg*:   0.9040697674418604
#
# radius: 140
# between-distance: 130
#
# avg*:   0.9011627906976744
#
# radius: 140
# between-distance: 150
#
# avg*:   0.9011627906976744

# %%
hm_detection_thresholds = [.01, .03, .05, .1, .2]
# pp_conflict_overlaps = [.2, .4, .6, .8]
# min_joint_distances = [0, 20, 40, 50, 70, 100, 150]

# ms_radius = [10, 20, 30, 40, 50, 60, 70, 90, 110, 120, 130, 140]
# ms_between_distances = [10, 30, 50, 60, 70, 90, 110, 120, 130, 150]

# radius/between
ms = [
    (60, 60),
    (50, 60),
    (40, 60),
    (30, 60),
    (20, 60),
    (60, 30),
    (60, 20),
    (120, 130)
]
# TESTS = []

# for th in hm_detection_thresholds:
#     for radius, between_distance in ms:
        
#         _START = time()
#         print('\n--- next step ---')
#         print('threshold:', th)
#         print('radius:', radius)
#         print('between_distance:', between_distance)
        
#         valid_frames = list(range(350, 470, 2)) + list(range(650, 750, 2))
#         params = get_settings(scale_to_mm=1000,
#                           hm_detection_threshold=th,
#                           pp_conflict_overlap=0.4,
#                           ms_radius=radius,
#                           ms_between_distance=between_distance)
        
        
#         PER_GTID = {}
#         TESTS.append(PER_GTID)
#         for frame in valid_frames:
#             _start = time()
#             L_Arms, U_Arms, L_Legs, U_Legs, GTIDs =\
#                 generate_pcp_score(frame, params)
#             _end = time()
#             #print('frame ' + str(frame) + ', elapsed:', _end - _start)
#             if len(L_Arms) > 0:
#                 for gtid, larms, uarms, llegs, ulegs in zip(
#                     GTIDs, L_Arms, U_Arms, L_Legs, U_Legs
#                 ):
#                     if not gtid in PER_GTID:
#                         PER_GTID[gtid] = {
#                             'larms': [],
#                             'uarms': [],
#                             'llegs': [],
#                             'ulegs': [],
#                             'frame': []
#                         }
#                     PER_GTID[gtid]['larms'].append(larms)
#                     PER_GTID[gtid]['uarms'].append(uarms)
#                     PER_GTID[gtid]['llegs'].append(llegs)
#                     PER_GTID[gtid]['ulegs'].append(ulegs)
#                     PER_GTID[gtid]['frame'].append(frame)
#                     #AVG.append((larms + uarms + llegs + ulegs)/4)
#         _END = time()
#         print('total step ELAPSED:', _END - _START)

        
# i = 0

# IMG = np.zeros((len(hm_detection_thresholds), len(ms)), 'float32')

# for a, th in enumerate(hm_detection_thresholds):
#     for b, meanshift in enumerate(ms):
#         print('threshold:', th)
#         print('radius/between_distance:', meanshift)
#         total_avg = []
        
#         PER_GTID = TESTS[i]
#         i += 1
        
#         for key, values in PER_GTID.items():
#             avg = np.mean([
#                 np.mean(values['uarms']),
#                 np.mean(values['larms']),
#                 np.mean(values['ulegs']),
#                 np.mean(values['llegs'])
#             ])
#             total_avg.append(avg)
# #             print('\tavg:  ', avg)
#         print('\navg*:  ', np.mean(total_avg))
#         IMG[a,b] = np.mean(total_avg)
#         print('')

# %%
#hm_detection_thresholds = [.01, .03, .05, .1, .2]
#pp_conflict_overlaps = [.2, .4, .6, .8]
# min_joint_distances = [0, 20, 40, 50, 70, 100, 150]

# ms_radius = [10, 20, 30, 40, 50, 60, 70, 90, 110, 120, 130, 140]
# ms_between_distances = [10, 30, 50, 60, 70, 90, 110, 120, 130, 150]

# radius/between
# ms = [
#     (60, 60),
#     (50, 60),
#     (40, 60),
#     (30, 60),
#     (20, 60),
#     (60, 30),
#     (60, 20),
#     (120, 130)
# ]
# TESTS = []

# for th in pp_conflict_overlaps:
#     for radius, between_distance in ms:
        
#         _START = time()
#         print('\n--- next step ---')
#         print('threshold:', th)
#         print('radius:', radius)
#         print('between_distance:', between_distance)
        
#         valid_frames = list(range(350, 470, 2)) + list(range(650, 750, 2))
#         params = get_settings(scale_to_mm=1000,
#                           hm_detection_threshold=0.03,
#                           pp_conflict_overlap=th,
#                           ms_radius=radius,
#                           ms_between_distance=between_distance)
        
        
#         PER_GTID = {}
#         TESTS.append(PER_GTID)
#         for frame in valid_frames:
#             _start = time()
#             L_Arms, U_Arms, L_Legs, U_Legs, GTIDs =\
#                 generate_pcp_score(frame, params)
#             _end = time()
#             #print('frame ' + str(frame) + ', elapsed:', _end - _start)
#             if len(L_Arms) > 0:
#                 for gtid, larms, uarms, llegs, ulegs in zip(
#                     GTIDs, L_Arms, U_Arms, L_Legs, U_Legs
#                 ):
#                     if not gtid in PER_GTID:
#                         PER_GTID[gtid] = {
#                             'larms': [],
#                             'uarms': [],
#                             'llegs': [],
#                             'ulegs': [],
#                             'frame': []
#                         }
#                     PER_GTID[gtid]['larms'].append(larms)
#                     PER_GTID[gtid]['uarms'].append(uarms)
#                     PER_GTID[gtid]['llegs'].append(llegs)
#                     PER_GTID[gtid]['ulegs'].append(ulegs)
#                     PER_GTID[gtid]['frame'].append(frame)
#                     #AVG.append((larms + uarms + llegs + ulegs)/4)
#         _END = time()
#         print('total step ELAPSED:', _END - _START)

        
# i = 0

# IMG = np.zeros((len(hm_detection_thresholds), len(ms)), 'float32')

# for a, th in enumerate(hm_detection_thresholds):
#     for b, meanshift in enumerate(ms):
#         print('threshold:', th)
#         print('radius/between_distance:', meanshift)
#         total_avg = []
        
#         PER_GTID = TESTS[i]
#         i += 1
        
#         for key, values in PER_GTID.items():
#             avg = np.mean([
#                 np.mean(values['uarms']),
#                 np.mean(values['larms']),
#                 np.mean(values['ulegs']),
#                 np.mean(values['llegs'])
#             ])
#             total_avg.append(avg)
# #             print('\tavg:  ', avg)
#         print('\navg*:  ', np.mean(total_avg))
#         IMG[a,b] = np.mean(total_avg)
#         print('')

# %%
# fig = plt.figure(figsize=(10, 12))
# ax = fig.add_subplot(111)

# heatmap = ax.pcolor(IMG)
# cbar = plt.colorbar(heatmap)

# plt.show()

# %%
# min_joint_distances = [0, 20, 40, 50, 70, 100, 150]

# TESTS = []
# for mj in min_joint_distances:            
#     _START = time()
#     print('\n--- next step ---')
#     print('min joint distance:', mj)

#     valid_frames = list(range(350, 470, 2)) + list(range(650, 750, 2))
#     params = get_settings(scale_to_mm=1000,
#                       hm_detection_threshold=0.05,
#                       pp_conflict_overlap=0.4,
#                       min_joint_distance=mj,
#                       ms_radius=60,
#                       ms_between_distance=60)


#     PER_GTID = {}
#     TESTS.append(PER_GTID)
#     for frame in valid_frames:
#         _start = time()
#         L_Arms, U_Arms, L_Legs, U_Legs, GTIDs =\
#             generate_pcp_score(frame, params)
#         _end = time()
#         #print('frame ' + str(frame) + ', elapsed:', _end - _start)
#         if len(L_Arms) > 0:
#             for gtid, larms, uarms, llegs, ulegs in zip(
#                 GTIDs, L_Arms, U_Arms, L_Legs, U_Legs
#             ):
#                 if not gtid in PER_GTID:
#                     PER_GTID[gtid] = {
#                         'larms': [],
#                         'uarms': [],
#                         'llegs': [],
#                         'ulegs': [],
#                         'frame': []
#                     }
#                 PER_GTID[gtid]['larms'].append(larms)
#                 PER_GTID[gtid]['uarms'].append(uarms)
#                 PER_GTID[gtid]['llegs'].append(llegs)
#                 PER_GTID[gtid]['ulegs'].append(ulegs)
#                 PER_GTID[gtid]['frame'].append(frame)
#                 #AVG.append((larms + uarms + llegs + ulegs)/4)
#     _END = time()
#     print('total step ELAPSED:', _END - _START)
    

# RESULT = []
# for i, mj in enumerate(min_joint_distances): 
#     print('min joint distance', mj)
#     PER_GTID = TESTS[i]
    
#     total_avg = []
#     for key, values in PER_GTID.items():
#         avg = np.mean([
#             np.mean(values['uarms']),
#             np.mean(values['larms']),
#             np.mean(values['ulegs']),
#             np.mean(values['llegs'])
#         ])
#         total_avg.append(avg)
#     print('avg*:  ', np.mean(total_avg))
#     print('\n')
#     RESULT.append(np.mean(total_avg))
    

# plt.plot(range(len(RESULT)), RESULT)
